# %%
import pandas as pd

# %%
"""
Clean stations data.
"""
import pandas as pd


# set constants
RAW_STATION_DATA = "/Users/ashanmu1/Documents/GitHub/bluebikes/data/raw/stations/current_bluebikes_stations.csv"

# load station data
station_df = pd.read_csv(RAW_STATION_DATA, skiprows=1)

# %%
station_df
# Out:
#      Number                                 Name   Latitude  Longitude  \
# 0    K32015                       1200 Beacon St  42.344149 -71.114674
# 1    W32006                       160 Arsenal St  42.364664 -71.175694
# 2    A32019                     175 N Harvard St  42.364475 -71.128408
# 3    S32035                        191 Beacon St  42.380323 -71.108786
# 4    C32094  2 Hummingbird Lane at Olmsted Green  42.288870 -71.095003
# ..      ...                                  ...        ...        ...
# 416  D32022                        West End Park  42.365908 -71.064467
# 417  N32005                          West Newton  42.349601 -71.226275
# 418  B32059            Whittier St Health Center  42.332863 -71.092189
# 419  D32040         Williams St at Washington St  42.306539 -71.107669
# 420  S32005                        Wilson Square  42.385676 -71.114121
#
#        District Public  Total docks
# 0     Brookline    Yes           15
# 1     Watertown    Yes           11
# ...

# %%
import matplotlib.pyplot as plt
import osmnx as ox
G = ox.graph_from_place('Somerville, MA', network_type='drive')
ox.plot_graph(G)
plt.show()

# %%
ox.projection.is_projected(G)
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ox.projection.is_projected(G)
#
# File ~/Documents/GitHub/bluebikes/venv/lib/python3.11/site-packages/osmnx/projection.py:26, in is_projected(crs)
#      10 def is_projected(crs):
#      11     """
#      12     Determine if a coordinate reference system is projected or not.
#      13
#    (...)
#      24         True if crs is projected, otherwise False
#      25     """
# ---> 26     return gpd.GeoSeries(crs=crs).crs.is_projected
#
# File ~/Documents/GitHub/bluebikes/venv/lib/python3.11/site-packages/geopandas/geoseries.py:213, in GeoSeries.__init__(self, data, index, crs, **kwargs)
#     211 # try to convert to GeometryArray, if fails return plain Series
#     212 try:
# --> 213     data = from_shapely(s.values, crs)
#     214 except TypeError:
#     215     raise TypeError(
# ...
